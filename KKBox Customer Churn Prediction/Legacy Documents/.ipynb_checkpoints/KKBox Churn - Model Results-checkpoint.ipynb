# %% [markdown]
# # Model Results

# %% [markdown]
# ### Attempt #1 - REPORT
# - Undersampled Dominant class to get and equal 50/50 split

# %% [markdown]
# ### - <font color=blue>Train Model</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created.items():
    results_temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results = train_results.append(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model1
# [[566749 106002]
#  [  2426  16722]]
#
# gbt_model2
# [[567315 105436]
#  [  2473  16675]]
#
# gbt_model3
# [[569319 103432]
#  [  2476  16672]]
#
# rfc_model1
# [[566108 106643]
#  [  3055  16093]]
#
# rfc_model2
# [[558445 114306]
#  [  2812  16336]]
#
# rfc_model3
# [[563722 109029]
#  [  3041  16107]]

# %%
# Evaluate Training Model
train_results
# Out:
#    resultname       AUC        f1  precision    recall
# 0  gbt_model1  0.857869  0.912689   0.842435  0.995738
# 0  gbt_model2  0.857062  0.913149   0.843276  0.995660
# 0  gbt_model3  0.858473  0.914897   0.846255  0.995670
# 0  rfc_model1  0.840968  0.911665   0.841482  0.994632
# 0  rfc_model2  0.841618  0.905086   0.830092  0.994990
# 0  rfc_model3  0.839560  0.909581   0.837936  0.994634

# %%
# Display feature importances
importances = gbt_model1.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#                  Features  Importance Score
# 22      spent_per_num_unq          0.229214
# 7       membership_length          0.082756
# 13         sum_over_50pec          0.080119
# 23  spent_per_num_repeats          0.059841
# 24           songs_last_7          0.056323
# 0       is_auto_renew_vec          0.051336
# 11            sum_num_unq          0.044655
# 80     num_repeat_last_60          0.037281
# 46        num_unq_last_15          0.028765
# 32      num_repeat_last_7          0.017492
# 25       songs_last_7_AVG          0.017181
# 84    over_75perc_last_60          0.016655
# 15        sum_over_985pec          0.015191
# 48     num_repeat_last_15          0.014603
# 96    num_repeat_last_120          0.014333

# %% [markdown]
# ### - <font color=blue>Validation Model</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, trainset) in models_created.items():
    results_temp = model1.transform(DRV_Feb2016)
    
    # Create a Dataframe of Train Results
    validation_results = validation_results.append(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model1
# [[418729 109475]
#  [  3368  16555]]
#
# gbt_model2
# [[420664 107540]
#  [  3470  16453]]
#
# gbt_model3
# [[425137 103067]
#  [  3482  16441]]
#
# rfc_model1
# [[437100  91104]
#  [  3716  16207]]
#
# rfc_model2
# [[429490  98714]
#  [  3449  16474]]
#
# rfc_model3
# [[431627  96577]
#  [  3718  16205]]

# %%
# Evaluate Validation Model
validation_results
# Out:
#    resultname       AUC        f1  precision    recall
# 0  gbt_model1  0.811845  0.881251   0.792741  0.992021
# 0  gbt_model2  0.811117  0.883429   0.796404  0.991819
# 0  gbt_model3  0.815050  0.888638   0.804873  0.991876
# 0  rfc_model1  0.820502  0.902144   0.827521  0.991570
# 0  rfc_model2  0.819999  0.893702   0.813114  0.992034
# 0  rfc_model3  0.815271  0.895906   0.817160  0.991460

# %% [markdown]
# ### Review
# - Although our False Negatives arent too bad, False Positives from our existing models are WAY too high. Especially with our use case, KKBox migh be losing more on treatment costs than on actual Churn Haha.
#
# ### Notes for Next Iteration
# - Make more Trend focused features
# - Create different split ratios of data 1-to-1 to 7-to-1, every odd.

# %% [markdown]
# ### Attempt #2
# - Multiple Split Ratio Training Sets
# - Bi-Weekly Aggregates
# - Comparative  Bi-Weekly Aggregates

# %% [markdown]
# ### - <font color=blue>Train Model</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created.items():
    results_temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results = train_results.append(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[586770  85981]
#  [  2199  16949]]
#
# gbt_model_2to1
# [[619914  52837]
#  [  3362  15786]]
#
# gbt_model_3to1
# [[635636  37115]
#  [  4462  14686]]
#
# gbt_model_5to1
# [[649186  23565]
#  [  6063  13085]]
#
# gbt_model_7to1
# [[656569  16182]
#  [  7342  11806]]
#
# rfc_model_1to1
# [[583797  88954]
#  [  2639  16509]]
#
# rfc_model_2to1
# [[627355  45396]
#  [  4641  14507]]
#
# rfc_model_3to1
# [[641019  31732]
#  [  5936  13212]]
#
# rfc_model_5to1
# [[658564  14187]
#  [  8729  10419]]
#
# rfc_model_7to1
# [[662660  10091]
#  [  9733   9415]]

# %%
# Evaluate Training Model
train_results
# Out:
#        resultname       AUC        f1  precision    recall
# 0  gbt_model_1to1  0.878676  0.930106   0.872195  0.996266
# 0  gbt_model_2to1  0.872941  0.956632   0.921461  0.994606
# 0  gbt_model_3to1  0.855902  0.968326   0.944831  0.993029
# 0  gbt_model_5to1  0.824167  0.977685   0.964972  0.990747
# 0  gbt_model_7to1  0.796256  0.982396   0.975947  0.988941
# 0  rfc_model_1to1  0.864977  0.927255   0.867776  0.995500
# 0  rfc_model_2to1  0.845073  0.961645   0.932522  0.992657
# 0  rfc_model_3to1  0.821413  0.971452   0.952832  0.990825
# 0  rfc_model_5to1  0.761521  0.982894   0.978912  0.986919
# 0  rfc_model_7to1  0.738348  0.985258   0.985000  0.985525

# %% [markdown]
# #### <font color=purple>Model Evaluation: Feature Importance</font>

# %%
# Display feature importances
importances = gbt_model_1to1.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#                         Features  Importance Score
# 114               STD_songs_0_15          0.156050
# 0              is_auto_renew_vec          0.109932
# 23             spent_per_num_unq          0.107839
# 24         spent_per_num_repeats          0.072705
# 7                net_paid_amount          0.048890
# 113               AVG_songs_0_15          0.043369
# 14                sum_over_50pec          0.041397
# 12                   sum_num_unq          0.034086
# 25                  songs_last_7          0.033015
# 8              membership_length          0.031654
# 111           STD_unq_songs_0_15          0.022599
# 26              songs_last_7_AVG          0.016393
# 16               sum_over_985pec          0.015384
# 181  DIFSUM_unq_songs_0_15_15_30          0.010254
# 10                  total_logins          0.010222

# %% [markdown]
# ### - <font color=blue>Validation Model</font> -

# %% [markdown]
# Document First and Last Model iterations
# - Summary of all changes

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, trainset) in models_created.items():
    results_temp = model1.transform(DRV_Feb2016)
    
    # Create a Dataframe of Train Results
    validation_results = validation_results.append(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=results_temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[447058  81146]
#  [  3120  16803]]
#
# gbt_model_2to1
# [[475745  52459]
#  [  5109  14814]]
#
# gbt_model_3to1
# [[492875  35329]
#  [  6368  13555]]
#
# gbt_model_5to1
# [[505798  22406]
#  [  8645  11278]]
#
# gbt_model_7to1
# [[512447  15757]
#  [ 10045   9878]]
#
# rfc_model_1to1
# [[455543  72661]
#  [  3420  16503]]
#
# rfc_model_2to1
# [[493448  34756]
#  [  6136  13787]]
#
# rfc_model_3to1
# [[503546  24658]
#  [  8022  11901]]
#
# rfc_model_5to1
# [[517627  10577]
#  [ 11412   8511]]
#
# rfc_model_7to1
# [[520489   7715]
#  [ 12512   7411]]

# %%
# Evaluate Validation Model
validation_results
# Out:
#        resultname       AUC        f1  precision    recall
# 0  gbt_model_1to1  0.844885  0.913867   0.846374  0.993069
# 0  gbt_model_2to1  0.822123  0.942944   0.900684  0.989375
# 0  gbt_model_3to1  0.806742  0.959412   0.933115  0.987245
# 0  gbt_model_5to1  0.761830  0.970214   0.957581  0.983195
# 0  gbt_model_7to1  0.732989  0.975438   0.970169  0.980775
# 0  rfc_model_1to1  0.845388  0.922925   0.862438  0.992548
# 0  rfc_model_2to1  0.813107  0.960209   0.934200  0.987718
# 0  rfc_model_3to1  0.775334  0.968565   0.953317  0.984319
# 0  rfc_model_5to1  0.703585  0.979197   0.979976  0.978429
# 0  rfc_model_7to1  0.678688  0.980935   0.985394  0.976525

# %% [markdown]
# ### Review
# - The New Features definitely helped. We were able to reduce our False Positives by ~20,000 while keeping our False Negatives consistent in the 1to1 (even split) Model.
# - RFC seems to be the best estimator so far, but let's hyperparameterize just to be sure.
#
# ### Notes for Next Iteration
# - Add additional feautres focused on previous cancelations as well as standard deviation versions of our aggregates.
# - Add 9-to-1, 11-to-1, and 13-to-1 Ratio Splits
# - Add Error score so we can better evaluate generalization

# %% [markdown]
# ### Attempt #3 REPORT

# %% [markdown]
# ### - <font color=blue>Train Model: All Seperate Models</font> -

# %%
## Create empty dataframe and populate with Train Set transformation results.
train_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created.items():
    temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results = train_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[594941  77810]
#  [  2284  16864]]
#
# gbt_model_3to1
# [[632669  40082]
#  [  4016  15132]]
#
# gbt_model_5to1
# [[650705  22046]
#  [  5798  13350]]
#
# gbt_model_7to1
# [[656859  15892]
#  [  6906  12242]]
#
# gbt_model_9to1
# [[661117  11634]
#  [  7843  11305]]
#
# gbt_model_11to1
# [[663448   9303]
#  [  8559  10589]]
#
# gbt_model_13to1
# [[664794   7957]
#  [  8991  10157]]
#
# rfc_model_1to1
# [[588893  83858]
#  [  3427  15721]]
#
# rfc_model_3to1
# [[648355  24396]
#  [  7147  12001]]
#
# rfc_model_5to1
# [[658823  13928]
#  [  9031  10117]]
#
# rfc_model_7to1
# [[662923   9828]
#  [  9964   9184]]
#
# rfc_model_9to1
# [[665318   7433]
#  [ 10984   8164]]
#
# rfc_model_11to1
# [[667167   5584]
#  [ 11860   7288]]
#
# rfc_model_13to1
# [[668667   4084]
#  [ 12714   6434]]

# %%
# Evaluate Training Model
train_results
# Out:
#         resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to1  0.882530  0.936928   0.884341  0.996176  0.118252
# 0   gbt_model_3to1  0.865343  0.966318   0.940421  0.993692  0.064775
# 0   gbt_model_5to1  0.832215  0.979048   0.967230  0.991168  0.040687
# 0   gbt_model_7to1  0.807857  0.982937   0.976378  0.989596  0.033206
# 0   gbt_model_9to1  0.786554  0.985478   0.982707  0.988276  0.028292
# 0  gbt_model_11to1  0.769590  0.986712   0.986172  0.987264  0.025892
# 0  gbt_model_13to1  0.759310  0.987409   0.988172  0.986656  0.024536
# 0   rfc_model_1to1  0.848188  0.930999   0.875351  0.994214  0.128435
# 0   rfc_model_3to1  0.795243  0.976247   0.963737  0.989097  0.045911
# 0   rfc_model_5to1  0.753827  0.982869   0.979297  0.986478  0.033235
# 0   rfc_model_7to1  0.732512  0.985287   0.985391  0.985192  0.028573
# 0   rfc_model_9to1  0.707657  0.986343   0.988951  0.983759  0.026510
# ...

# %% [markdown]
# #### <font color=purple>Model Evaluation: Optimal Parameters</font>

# %%
opti_params
# Out:
#          AUC            Model impurity  maxDepth  maxIter  minInstancesPerNode
# 16  0.943961   gbt_model_1to1      NaN         7     20.0                 10.0
# 17  0.943875   gbt_model_3to1      NaN         7     20.0                 20.0
# 17  0.943855   gbt_model_5to1      NaN         7     20.0                 20.0
# 16  0.943769   gbt_model_7to1      NaN         7     20.0                 10.0
# 17  0.943516   gbt_model_9to1      NaN         7     20.0                 20.0
# 16  0.941618  gbt_model_11to1      NaN         7     20.0                 10.0
# 6   0.913690  gbt_model_13to1  entropy         8      NaN                  NaN
# 13  0.920063   rfc_model_1to1     gini         8      NaN                  NaN
# 13  0.917307   rfc_model_3to1     gini         8      NaN                  NaN
# 6   0.913789   rfc_model_5to1  entropy         8      NaN                  NaN
# 6   0.916096   rfc_model_7to1  entropy         8      NaN                  NaN
# ...

# %% [markdown]
# #### <font color=purple>Model Evaluation: Feature Importance</font>

# %%
# Display feature importances
importances = rfc_model_1to1.bestModel.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#                   Features  Importance Score
# 105  login_after_expire_30          0.145527
# 104  login_after_expire_20          0.072148
# 13      total_transactions          0.067233
# 15         avg_spent_trans          0.057280
# 1          plan_list_price          0.049597
# 22      total_cancelations          0.043073
# 14             total_spent          0.041510
# 103  login_after_expire_10          0.032358
# 157    SUM_unq_songs_45_60          0.027794
# 160        SUM_songs_45_60          0.027739
# 169       SUM_logins_45_60          0.027281
# 3                is_cancel          0.025706
# 158    AVG_unq_songs_45_60          0.020317
# 0        payment_plan_days          0.018810
# 164         AVG_secs_45_60          0.018458

# %% [markdown]
# ### - <font color=blue>Validation Model: All Seperate Models</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created.items():
    temp = model1.transform(DRV_Feb2016)    
    
    # Create a Dataframe of Train Results
    validation_results = validation_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[453763  74441]
#  [  3729  16194]]
#
# gbt_model_3to1
# [[486877  41327]
#  [  5866  14057]]
#
# gbt_model_5to1
# [[500294  27910]
#  [  8353  11570]]
#
# gbt_model_7to1
# [[510507  17697]
#  [  9858  10065]]
#
# gbt_model_9to1
# [[515074  13130]
#  [ 10539   9384]]
#
# gbt_model_11to1
# [[517506  10698]
#  [ 11348   8575]]
#
# gbt_model_13to1
# [[518651   9553]
#  [ 11905   8018]]
#
# rfc_model_1to1
# [[459814  68390]
#  [  4268  15655]]
#
# rfc_model_3to1
# [[509452  18752]
#  [  8855  11068]]
#
# rfc_model_5to1
# [[517452  10752]
#  [ 11774   8149]]
#
# rfc_model_7to1
# [[520838   7366]
#  [ 12874   7049]]
#
# rfc_model_9to1
# [[522738   5466]
#  [ 13961   5962]]
#
# rfc_model_11to1
# [[523867   4337]
#  [ 14708   5215]]
#
# rfc_model_13to1
# [[525123   3081]
#  [ 15668   4255]]

# %%
# Evaluate Validation Model
validation_results
# Out:
#         resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to1  0.835949  0.920691   0.859068  0.991849  0.145932
# 0   gbt_model_3to1  0.813663  0.953770   0.921759  0.988095  0.087405
# 0   gbt_model_5to1  0.763948  0.965021   0.947161  0.983578  0.066549
# 0   gbt_model_7to1  0.735845  0.973716   0.966496  0.981056  0.050290
# 0   gbt_model_9to1  0.723078  0.977535   0.975142  0.979949  0.043091
# 0  gbt_model_11to1  0.705077  0.979139   0.979746  0.978542  0.040018
# 0  gbt_model_13to1  0.692182  0.979728   0.981914  0.977561  0.038872
# 0   rfc_model_1to1  0.828149  0.926772   0.870524  0.990803  0.135369
# 0   rfc_model_3to1  0.760019  0.973615   0.964499  0.982916  0.050570
# 0   rfc_model_5to1  0.694334  0.978692   0.979644  0.977752  0.040826
# 0   rfc_model_7to1  0.669933  0.980935   0.986055  0.975878  0.036537
# 0   rfc_model_9to1  0.644452  0.981752   0.989652  0.973987  0.034933
# ...

# %% [markdown]
# ### Review
# - In terms of Error the both RFC and GBT models seem to generalize well between Train and Validation sets. However the accuracy scores are a bit off. We are definitely overfitting on our Train set
# - Hyperparamterization seemed to give a slight bump in performance.
# - Overall we see an improvement with regards to AUC, F1, Precision, and Recall across the board. However, although our scores are high the False Positives and False Negatives on all the models are not optimal.
# - RFC models seem to have slightly highly Error Rates than GBT.
# - Although RFC seems to produce slightly better scores, when reviewing the confusion matrixes GBT seems to have a more favorable distribution. Due to this it would make sense to combine all GBT models and see if we can produce a better confusion matrix.
#
# ### Notes for Next Iteration
# - Consolidate GBT Model predictions into one. Train on RFC and GBT estimator

# %% [markdown]
# ### Attempt #4

# %% [markdown]
# ### - <font color=blue>Train Model: Consolidated Models of Binary Predictions</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train2_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(train_set)
    
    # Create a Dataframe of Train Results
    train2_results = train2_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model
# [[666200   6551]
#  [  9443   9705]]
#
# rfc_predict_model
# [[666199   6552]
#  [  9443   9705]]

# %%
train2_results
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model  0.748552  0.988133   0.990262  0.986024  0.023125
# 0  rfc_predict_model  0.748551  0.988133   0.990261  0.986024  0.023126

# %% [markdown]
# #### <font color=purple>Model Evaluation: Optimal Parameters</font>

# %%
opti_params
# Out:
#         AUC              Model impurity  maxDepth  maxIter  \
# 4  0.916455  gbt_predict_model      NaN         5     10.0
# 4  0.916478  rfc_predict_model  entropy         6      NaN
#
#    minInstancesPerNode
# 4                 10.0
# 4                  NaN

# %% [markdown]
# #### <font color=purple>Model Evaluation: Feature Importance</font>

# %%
# Display feature importances
importances = gbt_predict_model.bestModel.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#           Features  Importance Score
# 1   gbt_model_3to1          0.734012
# 6  gbt_model_13to1          0.085405
# 4   gbt_model_9to1          0.062893
# 0   gbt_model_1to1          0.056569
# 2   gbt_model_5to1          0.028965
# 3   gbt_model_7to1          0.023360
# 5  gbt_model_11to1          0.008795

# %%
# Display feature importances
importances = rfc_predict_model.bestModel.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#           Features  Importance Score
# 1   gbt_model_3to1          0.333698
# 2   gbt_model_5to1          0.283796
# 3   gbt_model_7to1          0.174987
# 4   gbt_model_9to1          0.068183
# 0   gbt_model_1to1          0.058307
# 6  gbt_model_13to1          0.051343
# 5  gbt_model_11to1          0.029685

# %% [markdown]
# ### - <font color=blue>Validation Model: Consolidated Model of Binary Predictions</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
valid_results2 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(Feb2016_predicts)
    
    # Create a Dataframe of Train Results
    valid_results2 = valid_results2.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model
# [[520519   7685]
#  [ 12653   7270]]
#
# rfc_predict_model
# [[520519   7685]
#  [ 12653   7270]]

# %%
# Evaluate Training Model
valid_results2
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model  0.675178  0.980833   0.985451  0.976268  0.036744
# 0  rfc_predict_model  0.675178  0.980833   0.985451  0.976268  0.036744

# %% [markdown]
# ### Review
# - When evaluating all scores the model seems to generalize well from Train to Validation. However, in terms of AUC our train model is clearly overfitting.
# - Looking at the Confusion Matrixes we see that the False Negatives increased quite substantially.
#
# ### Notes for Next Iteration
# - Run model on churn prediction probabilities instead of binary prediction values.

# %% [markdown]
# ### Attempt #5

# %% [markdown]
# ### - <font color=blue>Train Model: Consolidated Models of Prediction Probabilities</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train2_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(Jan2016_predicts)
    
    # Create a Dataframe of Train Results
    train2_results = train2_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model
# [[668432   4319]
#  [ 10643   8505]]
#
# rfc_predict_model
# [[669956   2795]
#  [ 11803   7345]]

# %%
train2_results
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model  0.718876  0.988927   0.993580  0.984327  0.021558
# 0  rfc_predict_model  0.689718  0.989218   0.995845  0.982687  0.020963

# %% [markdown]
# #### <font color=purple>Model Evaluation: Optimal Parameters</font>

# %%
opti_params
# Out:
#          AUC              Model impurity  maxDepth  maxIter  \
# 17  0.954768  gbt_predict_model      NaN         7     20.0
# 6   0.953368  rfc_predict_model  entropy         8      NaN
#
#     minInstancesPerNode
# 17                 20.0
# 6                   NaN

# %% [markdown]
# #### <font color=purple>Model Evaluation: Feature Importance</font>

# %%
# Display feature importances
importances = gbt_predict_model.bestModel.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#           Features  Importance Score
# 2   gbt_model_5to1          0.351964
# 4   gbt_model_9to1          0.306357
# 3   gbt_model_7to1          0.117440
# 0   gbt_model_1to1          0.089066
# 6  gbt_model_13to1          0.076173
# 5  gbt_model_11to1          0.031968
# 1   gbt_model_3to1          0.027031

# %%
# Display feature importances
importances = rfc_predict_model.bestModel.stages[-1].featureImportances
importances_list = [importances[i] for i in range(len(importances))]
names = final_features
pd.DataFrame(data=list(zip(names, importances_list)), columns=['Features', 'Importance Score']).sort_values(by='Importance Score', ascending=False).head(15)
# Out:
#           Features  Importance Score
# 4   gbt_model_9to1          0.328424
# 3   gbt_model_7to1          0.253671
# 2   gbt_model_5to1          0.150846
# 6  gbt_model_13to1          0.114990
# 5  gbt_model_11to1          0.099523
# 0   gbt_model_1to1          0.029359
# 1   gbt_model_3to1          0.023186

# %% [markdown]
# ### - <font color=blue>Validation Model: Consolidated Models of Prediction Probabilities</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
valid_results2 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(Feb2016_predicts)
    
    # Create a Dataframe of Train Results
    valid_results2 = valid_results2.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model
# [[523143   5061]
#  [ 13788   6135]]
#
# rfc_predict_model
# [[524692   3512]
#  [ 15073   4850]]

# %%
# Evaluate Training Model
valid_results2
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model  0.649177  0.982299   0.990418  0.974321  0.033914
# 0  rfc_predict_model  0.618394  0.982593   0.993351  0.972075  0.033286

# %% [markdown]
# ### Review
# - The prediction probability model did not lead to an improvement with respect to our confusion matrix and our False Negatives. However, since these numbers are continuous probabilities we can adjust the threshold to see if we can better tune the model.
# - In terms of generalization our Train model is overfitting quite substaintially.
#
# ### Notes for Next Iteration
# - Adjust thershold to different levels below 50%

# %% [markdown]
# ### Attempt #6

# %% [markdown]
# ### - <font color=blue>Train Model: Consolidated Models of Prediction Probabilities @ Adjusted Thresholds</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train2_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(train_set)
    
    # Create a Dataframe of Train Results
    train2_results = train2_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model1
# [[665010   7741]
#  [  8871  10277]]
#
# gbt_predict_model2
# [[663431   9320]
#  [  8266  10882]]
#
# rfc_predict_model1
# [[665010   7741]
#  [  8871  10277]]
#
# rfc_predict_model2
# [[663432   9319]
#  [  8266  10882]]

# %%
train2_results
# Out:
#            resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model1  0.762604  0.987659   0.988494  0.986836  0.024058
# 0  gbt_predict_model2  0.777228  0.986915   0.986146  0.987694  0.025513
# 0  rfc_predict_model1  0.762604  0.987659   0.988494  0.986836  0.024058
# 0  rfc_predict_model2  0.777229  0.986915   0.986148  0.987694  0.025512

# %% [markdown]
# ### - <font color=blue>Validation Model: Consolidated Models of Prediction Probabilities @ Adjusted Thresholds</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
valid_results2 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, predict_set) in consol_models_created.items():
    temp = model1.transform(predict_set)
    
    # Create a Dataframe of Train Results
    valid_results2 = valid_results2.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_predict_model1
# [[518992   9212]
#  [ 12200   7723]]
#
# gbt_predict_model2
# [[516800  11404]
#  [ 11574   8349]]
#
# rfc_predict_model1
# [[ 75059 453145]
#  [ 16874   3049]]
#
# rfc_predict_model2
# [[516820  11384]
#  [ 11657   8266]]

# %%
# Evaluate Training Model
valid_results2
# Out:
#            resultname       AUC        f1  precision    recall     error
# 0  gbt_predict_model1  0.685101  0.979783   0.982560  0.977033  0.038747
# 0  gbt_predict_model2  0.698737  0.978247   0.978410  0.978095  0.041676
# 0  rfc_predict_model1  0.147571  0.242070   0.142102  0.816453  0.836404
# 0  rfc_predict_model2  0.696673  0.978190   0.978448  0.977942  0.041777

# %% [markdown]
# ### Review
# - These are not generalizing well. After 6 attempts I have more than enough evidence of over fitting. Before performing anymore ensemble combos, let's go back and see if we can improve the original models by eliminating features.
# - Our Ensemble of models are only going to be as good as the base emodels. We need to improve that first before we do anything else. These models are getting us no where.
#
# ### Notes for Next Iteration
# Feature Elimination
# - Via Feature Importance Threshold  @ Mean, >.50 Quartile, >.25 Quartile

# %% [markdown]
# ### Attempt #7

# %% [markdown]
# ### - <font color=blue>Train Model: Mean </font> -

# %%
## Create empty dataframe and populate with Train Set transformation results.
train_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set_test) in models_created.items():
    temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results = train_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[594968  77783]
#  [  1721  17427]]
#
# gbt_model_3to1
# [[636501  36250]
#  [  3443  15705]]
#
# gbt_model_5to1
# [[649004  23747]
#  [  4677  14471]]
#
# gbt_model_7to1
# [[656057  16694]
#  [  5676  13472]]
#
# gbt_model_9to1
# [[660545  12206]
#  [  6646  12502]]
#
# gbt_model_11to1
# [[663281   9470]
#  [  7290  11858]]
#
# gbt_model_13to1
# [[665041   7710]
#  [  7913  11235]]

# %%
# Evaluate Training Model
train_results
# Out:
#         resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to1  0.897251  0.937366   0.884381  0.997116  0.114907
# 0   gbt_model_3to1  0.883153  0.969757   0.946117  0.994620  0.057368
# 0   gbt_model_5to1  0.860223  0.978566   0.964702  0.992845  0.041081
# 0   gbt_model_7to1  0.839379  0.983232   0.975185  0.991423  0.032331
# 0   gbt_model_9to1  0.817385  0.985926   0.981857  0.990039  0.027247
# 0  gbt_model_11to1  0.802602  0.987518   0.985923  0.989129  0.024223
# 0  gbt_model_13to1  0.787642  0.988385   0.988540  0.988241  0.022580

# %% [markdown]
# ### - <font color=blue>Validation Model: All Seperate Models - Mean</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created.items():
    temp = model1.transform(DRV_Feb2016)    
    
    # Create a Dataframe of Train Results
    validation_results = validation_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to1
# [[454287  73917]
#  [  2458  17465]]
#
# gbt_model_3to1
# [[489413  38791]
#  [  5419  14504]]
#
# gbt_model_5to1
# [[499368  28836]
#  [  6799  13124]]
#
# gbt_model_7to1
# [[505469  22735]
#  [  8293  11630]]
#
# gbt_model_9to1
# [[512723  15481]
#  [  9652  10271]]
#
# gbt_model_11to1
# [[516013  12191]
#  [ 10307   9616]]
#
# gbt_model_13to1
# [[519113   9091]
#  [ 11027   8896]]

# %%
# Evaluate Validation Model
validation_results
# Out:
#         resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to1  0.868342  0.922453   0.860060  0.994618  0.139338
# 0   gbt_model_3to1  0.827282  0.956780   0.926561  0.989049  0.080656
# 0   gbt_model_5to1  0.802072  0.965544   0.945407  0.986568  0.065012
# 0   gbt_model_7to1  0.770353  0.970217   0.956958  0.983858  0.056607
# 0   gbt_model_9to1  0.743113  0.976072   0.970691  0.981523  0.045853
# 0  gbt_model_11to1  0.729789  0.978660   0.976920  0.980417  0.041045
# 0  gbt_model_13to1  0.714654  0.980986   0.982789  0.979200  0.036703

# %% [markdown]
# ### - <font color=blue>Train Model: 75th Percentile</font> -

# %%
## Create empty dataframe and populate with Train Set transformation results.
train_results75 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set_test) in models_created75.items():
    temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results75 = train_results75.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to175
# [[593971  78780]
#  [  1614  17534]]
#
# gbt_model_3to175
# [[634809  37942]
#  [  3549  15599]]
#
# gbt_model_5to175
# [[650575  22176]
#  [  5207  13941]]
#
# gbt_model_7to175
# [[655842  16909]
#  [  6055  13093]]
#
# gbt_model_9to175
# [[660491  12260]
#  [  6995  12153]]
#
# gbt_model_11to175
# [[663392   9359]
#  [  7141  12007]]
#
# gbt_model_13to175
# [[665141   7610]
#  [  7616  11532]]

# %%
# Evaluate Training Model
train_results75
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to175  0.899304  0.936610   0.882899  0.997290  0.116193
# 0   gbt_model_3to175  0.879128  0.968349   0.943602  0.994440  0.059967
# 0   gbt_model_5to175  0.847551  0.979384   0.967037  0.992060  0.039577
# 0   gbt_model_7to175  0.829322  0.982789   0.974866  0.990852  0.033190
# 0   gbt_model_9to175  0.808232  0.985628   0.981776  0.989520  0.027829
# 0  gbt_model_11to175  0.806576  0.987712   0.986088  0.989350  0.023847
# 0  gbt_model_13to175  0.795472  0.988679   0.988688  0.988679  0.022006

# %% [markdown]
# ### - <font color=blue>Validation Model: All Seperate Models - 75th Percentile</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results75 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created75.items():
    temp = model1.transform(DRV_Feb2016)    
    
    # Create a Dataframe of Train Results
    validation_results75 = validation_results75.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to175
# [[453483  74721]
#  [  2508  17415]]
#
# gbt_model_3to175
# [[488032  40172]
#  [  5227  14696]]
#
# gbt_model_5to175
# [[504031  24173]
#  [  7410  12513]]
#
# gbt_model_7to175
# [[508939  19265]
#  [  7959  11964]]
#
# gbt_model_9to175
# [[514936  13268]
#  [  9790  10133]]
#
# gbt_model_11to175
# [[517218  10986]
#  [ 10449   9474]]
#
# gbt_model_13to175
# [[519263   8941]
#  [ 11172   8751]]

# %%
# Evaluate Validation Model
validation_results75
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to175  0.866326  0.921526   0.858538  0.994500  0.140896
# 0   gbt_model_3to175  0.830793  0.955550   0.923946  0.989403  0.082826
# 0   gbt_model_5to175  0.791152  0.969616   0.954235  0.985512  0.057620
# 0   gbt_model_7to175  0.782020  0.973946   0.963527  0.984602  0.049667
# 0   gbt_model_9to175  0.741745  0.978096   0.974881  0.981343  0.042067
# 0  gbt_model_11to175  0.727366  0.979694   0.979201  0.980198  0.039106
# 0  gbt_model_13to175  0.711157  0.980996   0.983073  0.978938  0.036694

# %% [markdown]
# ### - <font color=blue>Train Model: 50th Percentile</font> -

# %%
## Create empty dataframe and populate with Train Set transformation results.
train_results50 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set_test) in models_created50.items():
    temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results50 = train_results50.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to150
# [[592852  79899]
#  [  1580  17568]]
#
# gbt_model_3to150
# [[635443  37308]
#  [  3579  15569]]
#
# gbt_model_5to150
# [[650366  22385]
#  [  5175  13973]]
#
# gbt_model_7to150
# [[655266  17485]
#  [  5990  13158]]
#
# gbt_model_9to150
# [[660251  12500]
#  [  6898  12250]]
#
# gbt_model_11to150
# [[663544   9207]
#  [  7929  11219]]
#
# gbt_model_13to150
# [[664961   7790]
#  [  7455  11693]]

# %%
# Evaluate Training Model
train_results50
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to150  0.899360  0.935696   0.881235  0.997342  0.117761
# 0   gbt_model_3to150  0.878816  0.968826   0.944544  0.994399  0.059094
# 0   gbt_model_5to150  0.848231  0.979247   0.966726  0.992106  0.039832
# 0   gbt_model_7to150  0.830592  0.982398   0.974010  0.990941  0.033928
# 0   gbt_model_9to150  0.810587  0.985518   0.981420  0.989660  0.028036
# 0  gbt_model_11to150  0.786112  0.987247   0.986314  0.988192  0.024767
# 0  gbt_model_13to150  0.799542  0.988662   0.988421  0.988913  0.022034

# %% [markdown]
# ### - <font color=blue>Validation Model: All Seperate Models - 50th Percentile</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results50 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created50.items():
    temp = model1.transform(DRV_Feb2016)    
    
    # Create a Dataframe of Train Results
    validation_results50 = validation_results50.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to150
# [[452662  75542]
#  [  2485  17438]]
#
# gbt_model_3to150
# [[491275  36929]
#  [  5402  14521]]
#
# gbt_model_5to150
# [[503006  25198]
#  [  7071  12852]]
#
# gbt_model_7to150
# [[508864  19340]
#  [  8592  11331]]
#
# gbt_model_9to150
# [[514845  13359]
#  [  9742  10181]]
#
# gbt_model_11to150
# [[518388   9816]
#  [ 10753   9170]]
#
# gbt_model_13to150
# [[517884  10320]
#  [ 11064   8859]]

# %%
# Evaluate Validation Model
validation_results50
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to150  0.866127  0.920647   0.856983  0.994540  0.142352
# 0   gbt_model_3to150  0.829471  0.958692   0.930086  0.989124  0.077228
# 0   gbt_model_5to150  0.798689  0.968916   0.952295  0.986137  0.058871
# 0   gbt_model_7to150  0.766063  0.973283   0.963385  0.983396  0.050959
# 0   gbt_model_9to150  0.742863  0.978052   0.974709  0.981429  0.042145
# 0  gbt_model_11to150  0.720844  0.980542   0.981416  0.979678  0.037526
# 0  gbt_model_13to150  0.712562  0.979767   0.980462  0.979083  0.039013

# %% [markdown]
# ### - <font color=blue>Train Model: 25th Percentile</font> -

# %%
## Create empty dataframe and populate with Train Set transformation results.
train_results25 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set_test) in models_created25.items():
    temp = model1.transform(DRV_Jan2016)
    
    # Create a Dataframe of Train Results
    train_results25 = train_results25.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to125
# [[593924  78827]
#  [  1628  17520]]
#
# gbt_model_3to125
# [[635410  37341]
#  [  3561  15587]]
#
# gbt_model_5to125
# [[650206  22545]
#  [  5138  14010]]
#
# gbt_model_7to125
# [[655808  16943]
#  [  6087  13061]]
#
# gbt_model_9to125
# [[660598  12153]
#  [  6947  12201]]
#
# gbt_model_11to125
# [[663466   9285]
#  [  7861  11287]]
#
# gbt_model_13to125
# [[664879   7872]
#  [  8344  10804]]

# %%
# Evaluate Training Model
train_results25
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to125  0.898903  0.936560   0.882829  0.997266  0.116281
# 0   gbt_model_3to125  0.879261  0.968813   0.944495  0.994427  0.059116
# 0   gbt_model_5to125  0.849079  0.979151   0.966488  0.992160  0.040010
# 0   gbt_model_7to125  0.828462  0.982739   0.974815  0.990804  0.033285
# 0   gbt_model_9to125  0.809565  0.985744   0.981935  0.989593  0.027605
# 0  gbt_model_11to125  0.787830  0.987238   0.986198  0.988290  0.024781
# 0  gbt_model_13to125  0.776268  0.987947   0.988299  0.987606  0.023437

# %% [markdown]
# ### - <font color=blue>Validation Model: All Seperate Models - 25th Percentile</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
validation_results25 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in models_created25.items():
    temp = model1.transform(DRV_Feb2016)    
    
    # Create a Dataframe of Train Results
    validation_results25 = validation_results25.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# gbt_model_1to125
# [[453310  74894]
#  [  2562  17361]]
#
# gbt_model_3to125
# [[488838  39366]
#  [  5421  14502]]
#
# gbt_model_5to125
# [[503744  24460]
#  [  7290  12633]]
#
# gbt_model_7to125
# [[509083  19121]
#  [  8556  11367]]
#
# gbt_model_9to125
# [[515065  13139]
#  [  9732  10191]]
#
# gbt_model_11to125
# [[518272   9932]
#  [ 10687   9236]]
#
# gbt_model_13to125
# [[519808   8396]
#  [ 11110   8813]]

# %%
# Evaluate Validation Model
validation_results25
# Out:
#           resultname       AUC        f1  precision    recall     error
# 0   gbt_model_1to125  0.864807  0.921286   0.858210  0.994380  0.141310
# 0   gbt_model_3to125  0.826687  0.956192   0.925472  0.989032  0.081709
# 0   gbt_model_5to125  0.793892  0.969444   0.953692  0.985735  0.057925
# 0   gbt_model_7to125  0.767173  0.973531   0.963800  0.983471  0.050494
# 0   gbt_model_9to125  0.743322  0.978275   0.975125  0.981456  0.041726
# 0  gbt_model_11to125  0.722391  0.980491   0.981197  0.979796  0.037617
# 0  gbt_model_13to125  0.713229  0.981578   0.984105  0.979074  0.035587

# %% [markdown]
# ### Review
# - We selected the following GBT models based on generalization:
#
#
# - We selected the following RFC models based on generalization:
#   - rfc_model_1to125
#   - rfc_model_3to1
#   - rfc_model_5to1
#   - rfc_model_7to1
#   - rfc_model_9to1
#   - rfc_model_11to175
#   - rfc_model_13to1
#
# ### Notes for Next Iteration
# - Make ensemble model for each of these estimators

# %% [markdown]
# ### Attempt #8

# %% [markdown]
# ### - <font color=blue>Train Model: Consolidated Model of Optimal Mix</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
train2_results = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, train_set) in consol_models_created.items():
    temp = model1.transform(train_set)
    
    # Create a Dataframe of Train Results
    train2_results = train2_results.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# rfc_predict_model13
# [[664858   7893]
#  [  9010  10138]]
#
# rfc_predict_model9
# [[665995   6756]
#  [  9441   9707]]
#
# rfc_predict_model3
# [[666148   6603]
#  [  9514   9634]]
#
# rfc_predict_model1
# [[666169   6582]
#  [  9524   9624]]
#
# rfc_predict_model7
# [[665971   6780]
#  [  9428   9720]]
#
# rfc_predict_model11
# [[665761   6990]
#  [  9334   9814]]
#
# rfc_predict_model5
# [[666125   6626]
#  [  9509   9639]]

# %%
train2_results
# Out:
#             resultname       AUC        f1  precision    recall     error
# 0  rfc_predict_model13  0.758861  0.987443   0.988268  0.986629  0.024470
# 0   rfc_predict_model9  0.748452  0.987981   0.989958  0.986022  0.023418
# 0   rfc_predict_model3  0.746659  0.988042   0.990185  0.985919  0.023298
# 0   rfc_predict_model1  0.746414  0.988051   0.990216  0.985905  0.023281
# 0   rfc_predict_model7  0.748773  0.987973   0.989922  0.986041  0.023435
# 0  rfc_predict_model11  0.751072  0.987884   0.989610  0.986174  0.023609
# 0   rfc_predict_model5  0.746773  0.988029   0.990151  0.985926  0.023324

# %% [markdown]
# ### - <font color=blue>Validation Model: Consolidated Model of Optimal Mix</font> -

# %%
# Create empty dataframe and populate with Train Set transformation results.
valid_results2 = pd.DataFrame()

# Transform Train Sets
for model_name, (model1, predict_set) in consol_models_created.items():
    temp = model1.transform(predict_set)
    
    # Create a Dataframe of Train Results
    valid_results2 = valid_results2.append(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).evaluate())
    print('{}'.format(model_name))
    print(ClassEvaluator(resultname=model_name, resultdata=temp, model=model1).confusionmatrix())
    print(' ')
# Out:
# rfc_predict_model13
# [[519281   8923]
#  [ 12106   7817]]
#
# rfc_predict_model9
# [[520381   7823]
#  [ 12628   7295]]
#
# rfc_predict_model3
# [[520576   7628]
#  [ 12690   7233]]
#
# rfc_predict_model1
# [[520622   7582]
#  [ 12702   7221]]
#
# rfc_predict_model7
# [[520363   7841]
#  [ 12586   7337]]
#
# rfc_predict_model11
# [[520119   8085]
#  [ 12491   7432]]
#
# rfc_predict_model5
# [[520576   7628]
#  [ 12686   7237]]

# %%
# Evaluate Training Model
valid_results2
# Out:
#             resultname       AUC        f1  precision    recall     error
# 0  rfc_predict_model13  0.687734  0.980149   0.983107  0.977218  0.038067
# 0   rfc_predict_model9  0.675675  0.980724   0.985189  0.976308  0.036951
# 0   rfc_predict_model3  0.674303  0.980854   0.985559  0.976203  0.036703
# 0   rfc_predict_model1  0.674046  0.980887   0.985646  0.976183  0.036640
# 0   rfc_predict_model7  0.676712  0.980745   0.985155  0.976384  0.036913
# 0  rfc_predict_model11  0.678865  0.980599   0.984693  0.976548  0.037195
# 0   rfc_predict_model5  0.674404  0.980857   0.985559  0.976211  0.036696

# %% [markdown]
# ### Attempt #9
